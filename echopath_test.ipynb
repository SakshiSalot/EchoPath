# %%
from ultralytics import YOLO

def main():
    model = YOLO(r"E:\\EchoPath\\runs\\detect\\runs\\echopath\\v1\\weights\\best.pt")

    for r in model.predict(
        source=r"E:\\EchoPath\\Video_Data",
        save=True,
        conf=0.4,
        stream=True,
        imgsz=640,
    ):
        pass

if __name__ == "__main__":
    main()
# Out:
# video 1/6 (frame 1/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 16.3ms
# video 1/6 (frame 2/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 20.3ms
# video 1/6 (frame 3/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 17.2ms
# video 1/6 (frame 4/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 11.9ms
# video 1/6 (frame 5/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 16.7ms
# video 1/6 (frame 6/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 13.0ms
# video 1/6 (frame 7/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 15.2ms
# video 1/6 (frame 8/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 28.8ms
# video 1/6 (frame 9/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 15.1ms
# video 1/6 (frame 10/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 17.7ms
# ...

# %% [markdown]
# ## V2

# %%
from ultralytics import YOLO

def main():
    model = YOLO(r"E:\\EchoPath\\runs\\detect\\runs\\echopath\\v2\\weights\\best.pt")

    for r in model.predict(
        source=r"E:\\EchoPath\\Video_Data",
        save=True,
        conf=0.4,
        stream=True,
        imgsz=640,
    ):
        pass

if __name__ == "__main__":
    main()
# Out:
# video 1/6 (frame 1/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 26.9ms
# video 1/6 (frame 2/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 12.1ms
# video 1/6 (frame 3/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 15.8ms
# video 1/6 (frame 4/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 40.1ms
# video 1/6 (frame 5/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 14.0ms
# video 1/6 (frame 6/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 12.0ms
# video 1/6 (frame 7/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 14.8ms
# video 1/6 (frame 8/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 19.4ms
# video 1/6 (frame 9/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 19.7ms
# video 1/6 (frame 10/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 11.6ms
# ...

# %% [markdown]
# ## NEW VIDEOS

# %%
from ultralytics import YOLO

def main():
    model = YOLO(r"E:\\EchoPath\\runs\\detect\\runs\\echopath\\v2\\weights\\best.pt")

    for r in model.predict(
        source=r"E:\\EchoPath\\Video_Data\\Phase_2",
        save=True,
        conf=0.4,
        stream=True,
        imgsz=640,
    ):
        pass

if __name__ == "__main__":
    main()
# Out:
# video 1/5 (frame 1/888) E:\EchoPath\Video_Data\Phase_2\acad_entry.mp4: 640x384 (no detections), 12.1ms
# video 1/5 (frame 2/888) E:\EchoPath\Video_Data\Phase_2\acad_entry.mp4: 640x384 (no detections), 16.7ms
# video 1/5 (frame 3/888) E:\EchoPath\Video_Data\Phase_2\acad_entry.mp4: 640x384 (no detections), 13.0ms
# video 1/5 (frame 4/888) E:\EchoPath\Video_Data\Phase_2\acad_entry.mp4: 640x384 (no detections), 12.3ms
# video 1/5 (frame 5/888) E:\EchoPath\Video_Data\Phase_2\acad_entry.mp4: 640x384 (no detections), 13.7ms
# video 1/5 (frame 6/888) E:\EchoPath\Video_Data\Phase_2\acad_entry.mp4: 640x384 (no detections), 18.7ms
# video 1/5 (frame 7/888) E:\EchoPath\Video_Data\Phase_2\acad_entry.mp4: 640x384 (no detections), 11.6ms
# video 1/5 (frame 8/888) E:\EchoPath\Video_Data\Phase_2\acad_entry.mp4: 640x384 (no detections), 12.9ms
# video 1/5 (frame 9/888) E:\EchoPath\Video_Data\Phase_2\acad_entry.mp4: 640x384 (no detections), 14.7ms
# ...

# %% [markdown]
# ## V3

# %%
from ultralytics import YOLO

def main():
    model = YOLO(r"E:\\EchoPath\\runs\\detect\\runs\\echopath\\v3\\weights\\best.pt")

    for r in model.predict(
        source=r"E:\EchoPath\Video_Data",
        save=True,
        conf=0.4,
        stream=True,
        imgsz=640,
    ):
        pass

if __name__ == "__main__":
    main()
# Out:
# video 1/13 (frame 1/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 79.0ms
# video 1/13 (frame 2/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 21.5ms
# video 1/13 (frame 3/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 14.9ms
# video 1/13 (frame 4/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 16.3ms
# video 1/13 (frame 5/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 15.2ms
# video 1/13 (frame 6/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 15.2ms
# video 1/13 (frame 7/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 11.5ms
# video 1/13 (frame 8/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 18.0ms
# video 1/13 (frame 9/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 24.6ms
# video 1/13 (frame 10/566) E:\EchoPath\Video_Data\Classroom.MP4: 640x384 (no detections), 15.5ms
# ...
